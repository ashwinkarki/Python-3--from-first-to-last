# %%
#
# Read and write files using the built-in Python file methods
#

def main():  
  # Open a file for writing and create it if it doesn't exist(write mode=w)
 # d=open("textfile.txt","w+")

  # Open the file for appending text to the end(append mode=a)
  #d=open("textfile.txt","a")
    
  # Open the file for reading text to the end(read mode=r)
  d=open("textfile.txt","r")  

  # write some lines of data to the file
  #for i in range(1,10):
   #     d.write("f is line"+str(i)+"\r\n")
  
  # close the file when done
  #d.close()
  
  # Open the file back up and read the contents
  if d.mode=='r':
    #contents=d.read()
    fl=d.readlines()
    for x in fl:
        print(x)
    #print(contents)
    
if __name__ == "__main__":
  main()
# Out:
# f is line1
#
#
#
# f is line2
#
#
#
# f is line3
#
#
#
# f is line4
#
#
#
# f is line5
#
#
#
# f is line6
#
#
#
# f is line7
#
#
#
# f is line8
#
#
#
# f is line9
#
#
#
# f is line1
#
#
#
# f is line2
#
#
#
# f is line3
#
#
#
# f is line4
#
#
#
# f is line5
#
#
#
# f is line6
#
#
#
# f is line7
#
#
#
# f is line8
#
#
#
# f is line9
