# %%
# 
# Example file for parsing and processing JSON
#
import urllib.request 
import json


def printResults(data):
  # Use the json module to load the string data into a dictionary
  # now we can access the contents of the JSON like any other Python object
  theJSON = json.loads(data)
  if "title" in theJSON["metadata"]:
    print(theJSON["metadata"]["title"])
  print('......................\n')


  # output the number of events, plus the magnitude and each event name  
  count=theJSON["metadata"]["count"]
  print(str(count) +"record counted")
  print('......................\n')

  # for each event, print the place where it occurred
  for i in theJSON["features"]:
    print(i["properties"]["place"])
  print('......................')

  # print the events that only have a magnitude greater than 4
  for i in theJSON["features"]:
    if i["properties"]["mag"]>4.0:
        print ("%2.1f" % i["properties"]["mag"], i["properties"]["place"])
  print('...................... \n')
    
      
  # print only the events where at least 1 person reported feeling something
  print ("\n\nEvents that were felt:")
  for i in theJSON["features"]:
    feltReports = i["properties"]["felt"]
    if (feltReports != None):
      if (feltReports > 0):
        print ("%2.1f" % i["properties"]["mag"], i["properties"]["place"], " reported " + str(feltReports) + " times")
  
  
def main():
  # define a variable to hold the source URL
  # In this case we'll use the free data feed from the USGS
  # This feed lists all earthquakes for the last day larger than Mag 2.5
  urlData = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson"

  # Open the URL and read the data
  webUrl = urllib.request.urlopen(urlData)
  print ("result code: " + str(webUrl.getcode()))
  if (webUrl.getcode()==200):
        data=webUrl.read()
        printResults(data)
  else:
    print("recevied error")
if __name__ == "__main__":
  main()
# Out:
# result code: 200
# USGS Magnitude 2.5+ Earthquakes, Past Day
# ......................
#
# 43record counted
# ......................
#
# 18km SSE of Big Bear Lake, CA
# 21 km NNE of Ishigaki, Japan
# 22km ESE of Little Lake, CA
# 17 km W of Anchor Point, Alaska
# 60 km S of Whites City, New Mexico
# 27 km E of Honaunau-Napoopoo, Hawaii
# 5 km SSE of Guánica, Puerto Rico
# South Sandwich Islands region
# 16km SE of Lone Pine, CA
# 30 km SE of Mina, Nevada
# south of the Kermadec Islands
# 6km NNE of San Juan Bautista, CA
# 23 km W of Stanley, Idaho
# South Shetland Islands
# 283 km NE of Fais, Micronesia
# 21km WNW of Petrolia, CA
# 173 km SSW of Kroya, Indonesia
# 106 km NW of Vallenar, Chile
# Banda Sea
# 3 km NE of Jordán, Colombia
# 77 km WSW of Palana, Russia
# southwest of Africa
# 120 km NW of Vallenar, Chile
# 3 km SW of Guánica, Puerto Rico
# 269 km WSW of Tual, Indonesia
# 106 km NW of Vallenar, Chile
# 261 km SSE of Latung, Philippines
# 4 km ENE of Fukui-shi, Japan
# 143 km WSW of Adak, Alaska
# South Shetland Islands
# 9 km S of Ivanof Bay, Alaska
# South Sandwich Islands region
# 121 km NW of Vallenar, Chile
# 142 km ESE of Namie, Japan
# 74 km W of Akhiok, Alaska
# Owen Fracture Zone region
# Owen Fracture Zone region
# 10 km S of Volcano, Hawaii
# 233 km E of Levuka, Fiji
# Rat Islands, Aleutian Islands, Alaska
# 90km ESE of Maneadero, B.C., MX
# 134 km WNW of Neiafu, Tonga
# 10 km SSE of Esperanza, Puerto Rico
# ......................
# 4.4 21 km NNE of Ishigaki, Japan
# 4.9 South Sandwich Islands region
# 5.2 south of the Kermadec Islands
# 4.6 South Shetland Islands
# 4.9 283 km NE of Fais, Micronesia
# 4.8 173 km SSW of Kroya, Indonesia
# 5.2 Banda Sea
# 4.4 3 km NE of Jordán, Colombia
# 4.6 77 km WSW of Palana, Russia
# 5.0 southwest of Africa
# 4.2 120 km NW of Vallenar, Chile
# 4.5 269 km WSW of Tual, Indonesia
# 4.4 106 km NW of Vallenar, Chile
# 4.5 261 km SSE of Latung, Philippines
# 4.5 4 km ENE of Fukui-shi, Japan
# 4.4 143 km WSW of Adak, Alaska
# 5.0 South Shetland Islands
# 4.9 South Sandwich Islands region
# 4.4 121 km NW of Vallenar, Chile
# 5.3 142 km ESE of Namie, Japan
# 4.5 Owen Fracture Zone region
# 4.5 Owen Fracture Zone region
# 4.5 233 km E of Levuka, Fiji
# 4.8 134 km WNW of Neiafu, Tonga
# ......................
#
#
# Events that were felt:
# 3.2 18km SSE of Big Bear Lake, CA  reported 36 times
# 3.3 17 km W of Anchor Point, Alaska  reported 7 times
# 2.9 6km NNE of San Juan Bautista, CA  reported 11 times
# 2.8 21km WNW of Petrolia, CA  reported 1 times
# 5.2 Banda Sea  reported 1 times
# 4.5 4 km ENE of Fukui-shi, Japan  reported 1 times
# 4.4 143 km WSW of Adak, Alaska  reported 1 times
# 3.5 10 km SSE of Esperanza, Puerto Rico  reported 3 times
